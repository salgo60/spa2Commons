# %% [markdown]
# * [#59](https://github.com/salgo60/spa2Commons/issues/59)
# * [59_SPA_dubbletter_2](https://github.com/salgo60/spa2Commons/blob/main/Notebook/59_SPA_dubbletter_2.ipynb)
#
# SPA dubbletter

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-03-13 14:38:52.816728

# %%
# !pip install scikit-image opencv-python
# Out:
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 9.4 MB/s eta 0:00:000:00:010:00:01
# Using cached opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.6 MB/s eta 0:00:004 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 9.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.5 MB/s eta 0:00:009.8 MB/s eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 9.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12

# %%
from pathlib import Path
import cv2
from skimage.metrics import structural_similarity as ssim

image_dir = Path("SPAtestpictures")

images = list(image_dir.glob("*.jpg"))

def load_gray(path):
    img = cv2.imread(str(path))
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

for i in range(len(images)):
    for j in range(i+1, len(images)):

        img1 = load_gray(images[i])
        img2 = load_gray(images[j])

        img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

        score, _ = ssim(img1, img2, full=True)

        if score > 0.90:
            print(images[i].name, "≈", images[j].name, "SSIM:", round(score,3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from pathlib import Path
#       2 import cv2
# ----> 3 from skimage.metrics import structural_similarity as ssim
#       5 image_dir = Path("SPAtestpictures")
#       7 images = list(image_dir.glob("*.jpg"))
#
# ModuleNotFoundError: No module named 'skimage'

# %%
from datetime import datetime
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2026-03-13 14:39:07.960796
# Time elapsed (hh:mm:ss.ms) 0:00:15.144168
