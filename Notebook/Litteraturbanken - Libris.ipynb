# %% [markdown]
# ### Hitta poster med Libris-URI
#
#
# Denna [Notebook](https://github.com/salgo60/spa2Commons/blob/main/Notebook/Litteraturbanken%20-%20Libris.ipynb)
#
# * alla poster i Litteraturbanken skall ha samma LIBRIS-URI

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2023-03-02 19:34:40.187117

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
 
url = "https://litteraturbanken.se/api/get_authors"
r = http.request('GET', url)
data = json.loads(r.data)
df = pd.json_normalize(data["data"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4874 entries, 0 to 4873
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   authorid                       4874 non-null   object
#  1   authorid_norm                  4874 non-null   object
#  2   db_checksum                    4874 non-null   object
#  3   db_timestamp                   4874 non-null   int64
#  4   doc_type                       4874 non-null   object
#  5   full_name                      4874 non-null   object
#  6   gender                         4874 non-null   object
#  7   imported                       4237 non-null   object
#  8   intro                          752 non-null    object
#  9   name_for_index                 4874 non-null   object
#  10  pictureinfo                    246 non-null    object
#  11  searchable                     4874 non-null   bool
#  12  show                           4874 non-null   bool
#  13  surname                        4874 non-null   object
#  14  updated                        4237 non-null   object
#  15  birth.date                     4572 non-null   object
#  16  birth.plain                    4874 non-null   object
#  17  death.date                     2754 non-null   object
#  18  death.plain                    4135 non-null   object
#  19  librisid                       2800 non-null   object
#  20  wikidata.birthplace            2240 non-null   object
#  21  wikidata.birthplace_label      2240 non-null   object
#  22  wikidata.deathplace            1934 non-null   object
#  23  wikidata.deathplace_label      1934 non-null   object
#  24  wikidata.image                 1750 non-null   object
#  25  wikidata.sbl_link              901 non-null    object
#  26  wikidata.skbl_link             174 non-null    object
#  27  wikidata.sol_link              144 non-null    object
#  28  wikidata.wikidata_id           3022 non-null   object
#  29  wikidata.wikipedia             2174 non-null   object
#  30  db_timestamp_updated           3017 non-null   float64
#  31  intro_text                     752 non-null    object
#  32  popularity                     2509 non-null   float64
#  33  pseudonym                      154 non-null    object
#  34  dramawebben.intro              114 non-null    object
#  35  dramawebben.intro_author       113 non-null    object
#  36  dramawebben.intro_author_norm  113 non-null    object
#  37  dramawebben.legacy_url         127 non-null    object
#  38  dramawebben.picture            82 non-null     object
#  39  sources                        544 non-null    object
#  40  other_name                     115 non-null    object
#  41  intro_author                   419 non-null    object
#  42  intro_author_norm              419 non-null    object
#  43  dramawebben.picture_info       76 non-null     object
#  44  picture                        334 non-null    object
#  45  bibliography                   19 non-null     object
#  46  external_ref                   9 non-null      object
#  47  presentation                   37 non-null     object
#  48  seemore                        4 non-null      object
#  49  dramawebben.sources            6 non-null      object
# dtypes: bool(2), float64(2), int64(1), object(45)
# memory usage: 1.8+ MB

# %%
#just objects with show = True --> displayed in the web
dfShowTrue = df[df["show"] == True].copy()
dfShowLibris = dfShowTrue[~dfShowTrue.librisid.isnull()]
dfShowLibris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2214 entries, 2 to 4872
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   authorid                       2214 non-null   object
#  1   authorid_norm                  2214 non-null   object
#  2   db_checksum                    2214 non-null   object
#  3   db_timestamp                   2214 non-null   int64
#  4   doc_type                       2214 non-null   object
#  5   full_name                      2214 non-null   object
#  6   gender                         2214 non-null   object
#  7   imported                       2214 non-null   object
#  8   intro                          610 non-null    object
#  9   name_for_index                 2214 non-null   object
#  10  pictureinfo                    229 non-null    object
#  11  searchable                     2214 non-null   bool
#  12  show                           2214 non-null   bool
#  13  surname                        2214 non-null   object
#  14  updated                        2214 non-null   object
#  15  birth.date                     2049 non-null   object
#  16  birth.plain                    2214 non-null   object
#  17  death.date                     1457 non-null   object
#  18  death.plain                    2071 non-null   object
#  19  librisid                       2214 non-null   object
#  20  wikidata.birthplace            1757 non-null   object
#  21  wikidata.birthplace_label      1757 non-null   object
#  22  wikidata.deathplace            1553 non-null   object
#  23  wikidata.deathplace_label      1553 non-null   object
#  24  wikidata.image                 1428 non-null   object
#  25  wikidata.sbl_link              766 non-null    object
#  26  wikidata.skbl_link             140 non-null    object
#  27  wikidata.sol_link              133 non-null    object
#  28  wikidata.wikidata_id           2182 non-null   object
#  29  wikidata.wikipedia             1704 non-null   object
#  30  db_timestamp_updated           1899 non-null   float64
#  31  intro_text                     610 non-null    object
#  32  popularity                     1664 non-null   float64
#  33  pseudonym                      107 non-null    object
#  34  dramawebben.intro              79 non-null     object
#  35  dramawebben.intro_author       79 non-null     object
#  36  dramawebben.intro_author_norm  79 non-null     object
#  37  dramawebben.legacy_url         82 non-null     object
#  38  dramawebben.picture            62 non-null     object
#  39  sources                        465 non-null    object
#  40  other_name                     76 non-null     object
#  41  intro_author                   349 non-null    object
#  42  intro_author_norm              349 non-null    object
#  43  dramawebben.picture_info       59 non-null     object
#  44  picture                        294 non-null    object
#  45  bibliography                   17 non-null     object
#  46  external_ref                   8 non-null      object
#  47  presentation                   32 non-null     object
#  48  seemore                        4 non-null      object
#  49  dramawebben.sources            6 non-null      object
# dtypes: bool(2), float64(2), int64(1), object(45)
# memory usage: 851.9+ KB

# %%
dfShowLibris.head()
# Out:
#      authorid authorid_norm                       db_checksum   db_timestamp  \
# 2      AasenE        AasenE  f9d8d6666830bbe11a5153518eb5ca7b  1675080015010
# 3    AbeniusM      AbeniusM  76499012e7c07728be855a7b41a14baf  1675080014912
# 7   AchariusE     AchariusE  16d1feaaed2220a90cbf00b840d42922  1675080015152
# 8     AckeJAG       AckeJAG  47deedb8097383e2c545c42562445072  1675080015574
# 9  AdamBremen    AdamBremen  4ec10eece1b1cf51d645b0966da4c006  1675080016261
#
#   doc_type        full_name  gender    imported  \
# 2   author  Elisabeth Aasen  female  2014-03-13
# 3   author   Margit Abenius  female  2017-04-14
# 7   author    Erik Acharius    male  2018-02-01
# 8   author    J. A. G. Acke    male  2020-09-21
# 9   author   Adam av Bremen    male  2014-02-05
#
#                                                intro    name_for_index  \
# 2                                               None  Aasen, Elisabeth
# 3  \n<p>MARGIT ABENIUS (1899–1970): ”Margit Abeni...   Abenius, Margit
# 7  \n<p>ERIK ACHARIUS (1757–1819): ”botaniker, Li...    Acharius, Erik
# 8                                               None    Acke, J. A. G.
# 9                                               None    Adam av Bremen
#
#   pictureinfo  searchable  show         surname     updated birth.date  \
# 2        None       False  True           Aasen  2019-10-16       1935
# 3        None        True  True         Abenius  2019-10-16       1899
# 7        None       False  True        Acharius  2019-10-16       1757
# 8        None        True  True            Acke  2020-09-21       1859
# 9        None        True  True  Adam av Bremen  2019-10-16       1066
#
#   birth.plain death.date death.plain         librisid  \
# 2        1935        NaN         NaN  53hlsf1p1mc2mpw
# 3        1899        NaN        1970  ljx00mt45v0dfx5
# 7        1757       1819        1819  dbqtx0hx5srsg85
# 8        1859       1924        1924  tr577tpc0k0tfc9
# 9        0000        NaN        1095  53hkk5vp1k798w1
#
#             wikidata.birthplace wikidata.birthplace_label  \
# 2                          None                      None
# 3         [14.614527777, 61.12]           Orsa församling
# 7  [17.138055555, 60.672777777]              Gävle Parish
# 8  [18.060111111, 59.337944444]     Adolf Fredriks parish
# 9       [13.4775, 51.163611111]                   Meissen
#
#             wikidata.deathplace   wikidata.deathplace_label  \
# 2                          None                        None
# 3  [17.721805555, 60.011805555]                 Lena Parish
# 7            [14.8917, 58.4507]  Vadstena church församling
# 8   [18.33192553, 59.404321035]                     Vaxholm
# 9                          None                        None
#
#                                       wikidata.image wikidata.sbl_link  \
# 2                                               None              None
# 3  http://commons.wikimedia.org/wiki/Special:File...              None
# 7  http://commons.wikimedia.org/wiki/Special:File...              5503
# 8  http://commons.wikimedia.org/wiki/Special:File...              5508
# 9                                               None              None
#
#   wikidata.skbl_link wikidata.sol_link wikidata.wikidata_id  \
# 2               None              None            Q11967131
# 3      MargitAbenius              None             Q4933592
# 7               None              None              Q365923
# 8               None              None             Q5541979
# 9               None              None              Q109244
#
#                              wikidata.wikipedia  db_timestamp_updated  \
# 2                                          None                   NaN
# 3  https://sv.wikipedia.org/wiki/Margit_Abenius          1.675080e+12
# 7   https://sv.wikipedia.org/wiki/Erik_Acharius          1.675080e+12
# 8     https://sv.wikipedia.org/wiki/J.A.G._Acke          1.675080e+12
# 9  https://sv.wikipedia.org/wiki/Adam_av_Bremen          1.677767e+12
#
#                                           intro_text  popularity pseudonym  \
# 2                                                NaN         NaN       NaN
# 3  \nMARGIT ABENIUS (1899–1970): ”Margit Abenius ...      2519.0       NaN
# 7  \nERIK ACHARIUS (1757–1819): ”botaniker, Linné...       133.0       NaN
# 8                                                NaN      7020.0       NaN
# 9                                                NaN     89550.0       NaN
#
#   dramawebben.intro dramawebben.intro_author dramawebben.intro_author_norm  \
# 2               NaN                      NaN                           NaN
# 3               NaN                      NaN                           NaN
# 7               NaN                      NaN                           NaN
# 8               NaN                      NaN                           NaN
# 9               NaN                      NaN                           NaN
#
#   dramawebben.legacy_url dramawebben.picture  \
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 7                    NaN                 NaN
# 8                    NaN                 NaN
# 9                    NaN                 NaN
#
#                                              sources  \
# 2                                                NaN
# 3                                                NaN
# 7  [Bernhard Meijer, <a href="/forfattare/MeijerB...
# 8                                                NaN
# 9                                                NaN
#
#                   other_name intro_author intro_author_norm  \
# 2                        NaN          NaN               NaN
# 3                        NaN          NaN               NaN
# 7                        NaN          NaN               NaN
# 8  [Acke, Johan Axel Gustaf]          NaN               NaN
# 9                        NaN          NaN               NaN
#
#   dramawebben.picture_info picture bibliography external_ref presentation  \
# 2                      NaN     NaN          NaN          NaN          NaN
# 3                      NaN     NaN          NaN          NaN          NaN
# 7                      NaN     NaN          NaN          NaN          NaN
# 8                      NaN     NaN          NaN          NaN          NaN
# 9                      NaN     NaN          NaN          NaN          NaN
#
#   seemore dramawebben.sources
# 2     NaN                 NaN
# 3     NaN                 NaN
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9     NaN                 NaN

# %% [markdown]
# ### Get Wikidata

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys,json
import pandas as pd 

from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

# https://w.wiki/4AAV
query = """SELECT (REPLACE(STR(?item), ".*Q", "Q") AS ?WikidataID)  ?authorid ?SBL ?SKBL WHERE {
# ?item wdt:P31 wd:Q5.
# ?item wdt:P5101 ?authorid
OPTIONAL {?item wdt:P3217 ?SBL}
OPTIONAL {?item wdt:P4963 ?SKBL}
} order by ?authorid"""
queryLIBRIS = """SELECT ?item (REPLACE(STR(?item), ".*Q", "Q") AS ?WikidataID)  ?authorid ?SBL ?SKBL (sample(?LIBRISXL) AS ?LIBRISXL)
 WHERE {
# ?item wdt:P31 wd:Q5.
# ?item wdt:P5101 ?authorid
OPTIONAL {?item wdt:P3217 ?SBL}
OPTIONAL {?item wdt:P5587 ?LIBRISXL}
OPTIONAL {?item wdt:P4963 ?SKBL}
} group by ?item ?WikidataID ?authorid ?SBL ?SKBL
order by ?authorid""" 
    
def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']
    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDLittbanktot = get_sparql_dataframe(endpoint_url, queryLIBRIS)

# %%
WDLittbanktot.head()
# Out:
#                                        item WikidataID      authorid   SBL  \
# 0  http://www.wikidata.org/entity/Q11967131  Q11967131        AasenE  None
# 1   http://www.wikidata.org/entity/Q4933592   Q4933592      AbeniusM  None
# 2  http://www.wikidata.org/entity/Q24680938  Q24680938  AbrahamssonA  None
# 3   http://www.wikidata.org/entity/Q4934135   Q4934135  AbrahamssonS  None
# 4    http://www.wikidata.org/entity/Q365923    Q365923     AchariusE  5503
#
#             SKBL         LIBRISXL
# 0           None  53hlsf1p1mc2mpw
# 1  MargitAbenius  ljx00mt45v0dfx5
# 2           None             None
# 3           None  gdsvx6k00h624cw
# 4           None  dbqtx0hx5srsg85

# %% [markdown]
# ### Compare Littbank Libris field with Wikidata

# %%
WDLittbank_WD_merge =  pd.merge(WDLittbanktot, dfShowLibris, on='authorid',indicator=True)
WDLittbank_WD_merge.rename(columns={"_merge": "WD_Littbank_merge_False"},inplace = True)

WDLittbank_WD_merge["WD_Littbank_merge_False"].value_counts()
# Out:
# both          2211
# left_only        0
# right_only       0
# Name: WD_Littbank_merge_False, dtype: int64

# %% [markdown]
# ## LIttbank Show LIBRIS

# %%
columnsShow = ['authorid', 'LIBRISXL', 'librisid']

# %%
WDLittbank_WD_merge[columnsShow]
# Out:
#         authorid         LIBRISXL         librisid
# 0         AasenE  53hlsf1p1mc2mpw  53hlsf1p1mc2mpw
# 1       AbeniusM  ljx00mt45v0dfx5  ljx00mt45v0dfx5
# 2      AchariusE  dbqtx0hx5srsg85  dbqtx0hx5srsg85
# 3        AckeJAG  tr577tpc0k0tfc9  tr577tpc0k0tfc9
# 4     AdamBremen  53hkk5vp1k798w1  53hkk5vp1k798w1
# ...          ...              ...              ...
# 2206   ÖlanderAH  nl0377n64tnsz8v  nl0377n64tnsz8v
# 2207      ÖmanVE  b8nqslxv3ln1qgp  b8nqslxv3ln1qgp
# 2208  ÖnnerforsA  qn246nn82v714bj  qn246nn82v714bj
# 2209  ÖstergrenC             None  rp369cv94738kb9
# 2210     ÖstmanK  1zcfh3wk04wqjs9  1zcfh3wk04wqjs9
#
# [2211 rows x 3 columns]

# %%
WDLittbank_WD_merge["diffLIBRIS"] = WDLittbank_WD_merge['LIBRISXL'] == WDLittbank_WD_merge['librisid']

# %%
columnsShow = ['authorid', 'LIBRISXL', 'librisid','diffLIBRIS']

# %%
WDLittbank_WD_merge["diffLIBRIS"].value_counts()
# Out:
# True     2128
# False      83
# Name: diffLIBRIS, dtype: int64

# %%
#WDLittbank_WD_merge_False[columnsShow]
WDLittbank_WD_Librisid_False = WDLittbank_WD_merge[WDLittbank_WD_merge["diffLIBRIS"] == False].copy()

# %%
WDLittbank_WD_Librisid_False.shape
# Out:
# (83, 57)

# %% [markdown]
# ### List to check

# %%
from IPython.display import HTML

WDLittbank_WD_Librisid_False["Littbank"] = "<a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/" + WDLittbank_WD_Librisid_False["authorid"] + "'>link</a>"
WDLittbank_WD_Librisid_False["LittAPI"] = "<a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/" + WDLittbank_WD_Librisid_False["authorid"] + "'>link</a>"
WDLittbank_WD_Librisid_False["LIBRIS_uri"] = "<a target=_blank href='https://libris.kb.se/" + WDLittbank_WD_Librisid_False["librisid"] + "'>link LIBRIS</a>"

WDLittbank_WD_Librisid_False["WD"] = "<a target=_blank href='https://www.wikidata.org/wiki/" + WDLittbank_WD_Librisid_False["WikidataID"] + "'>link WD</a>"

WDLittbank_WD_Librisid_False["WD_sök_Librisid"] = "<a target=_blank " \
   + "href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3D" + WDLittbank_WD_Librisid_False["librisid"] + "%22'>sök WD Librisid</a>"
 
pd.set_option("display.max.columns", None) 
HTML(WDLittbank_WD_Librisid_False[["Littbank","LittAPI","WD","WikidataID", "WD_sök_Librisid", \
                                   "authorid","LIBRISXL","librisid","LIBRIS_uri"]
                                 ].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Littbank</th>
#       <th>LittAPI</th>
#       <th>WD</th>
#       <th>WikidataID</th>
#       <th>WD_sök_Librisid</th>
#       <th>authorid</th>
#       <th>LIBRISXL</th>
#       <th>librisid</th>
#       <th>LIBRIS_uri</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/AhlbomM'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/AhlbomM'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q106594297'>link WD</a></td>
#       <td>Q106594297</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3D86lnhzfs1054pzr%22'>sök WD Librisid</a></td>
#       <td>AhlbomM</td>
#       <td>None</td>
#       <td>86lnhzfs1054pzr</td>
#       <td><a target=_blank href='https://libris.kb.se/86lnhzfs1054pzr'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/ArvidsonB'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/ArvidsonB'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q115954923'>link WD</a></td>
#       <td>Q115954923</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Ddbqsv7dx233m63v%22'>sök WD Librisid</a></td>
#       <td>ArvidsonB</td>
#       <td>None</td>
#       <td>dbqsv7dx233m63v</td>
#       <td><a target=_blank href='https://libris.kb.se/dbqsv7dx233m63v'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/AurellCJE'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/AurellCJE'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q110214453'>link WD</a></td>
#       <td>Q110214453</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3D75kmp3dr4fpghz2%22'>sök WD Librisid</a></td>
#       <td>AurellCJE</td>
#       <td>None</td>
#       <td>75kmp3dr4fpghz2</td>
#       <td><a target=_blank href='https://libris.kb.se/75kmp3dr4fpghz2'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>217</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BexellJG'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BexellJG'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q116739705'>link WD</a></td>
#       <td>Q116739705</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Dmkz25fm53xfw5sx%22'>sök WD Librisid</a></td>
#       <td>BexellJG</td>
#       <td>None</td>
#       <td>mkz25fm53xfw5sx</td>
#       <td><a target=_blank href='https://libris.kb.se/mkz25fm53xfw5sx'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>238</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BjörlingF'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BjörlingF'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q110760886'>link WD</a></td>
#       <td>Q110760886</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3D20dg93dl2tkzq4s%22'>sök WD Librisid</a></td>
#       <td>BjörlingF</td>
#       <td>None</td>
#       <td>20dg93dl2tkzq4s</td>
#       <td><a target=_blank href='https://libris.kb.se/20dg93dl2tkzq4s'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BlomL'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BlomL'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q11879928'>link WD</a></td>
#       <td>Q11879928</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Dtr572wjc2s9fzzl%22'>sök WD Librisid</a></td>
#       <td>BlomL</td>
#       <td>None</td>
#       <td>tr572wjc2s9fzzl</td>
#       <td><a target=_blank href='https://libris.kb.se/tr572wjc2s9fzzl'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>255</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BlumenbergHG'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BlumenbergHG'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q110754913'>link WD</a></td>
#       <td>Q110754913</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Db8nqs15v327fqmz%22'>sök WD Librisid</a></td>
#       <td>BlumenbergHG</td>
#       <td>None</td>
#       <td>b8nqs15v327fqmz</td>
#       <td><a target=_blank href='https://libris.kb.se/b8nqs15v327fqmz'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>282</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BoyeF'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BoyeF'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q5580892'>link WD</a></td>
#       <td>Q5580892</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Dhftwql715p52vzp%22'>sök WD Librisid</a></td>
#       <td>BoyeF</td>
#       <td>1zcgpj6k4m88f7r</td>
#       <td>hftwql715p52vzp</td>
#       <td><a target=_blank href='https://libris.kb.se/hftwql715p52vzp'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BrausewetterE'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BrausewetterE'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q124497'>link WD</a></td>
#       <td>Q124497</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3D241920%22'>sök WD Librisid</a></td>
#       <td>BrausewetterE</td>
#       <td>gdsvxxs0435cbmd</td>
#       <td>241920</td>
#       <td><a target=_blank href='https://libris.kb.se/241920'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>317</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BruzeliusJ'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BruzeliusJ'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q108845835'>link WD</a></td>
#       <td>Q108845835</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Dmkz13c951k5nz8t%22'>sök WD Librisid</a></td>
#       <td>BruzeliusJ</td>
#       <td>None</td>
#       <td>mkz13c951k5nz8t</td>
#       <td><a target=_blank href='https://libris.kb.se/mkz13c951k5nz8t'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BörkI'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/BörkI'>link</a></td>
#       <td><a target=_blank href='https://www.wikidata.org/wiki/Q108865163'>link WD</a></td>
#       <td>Q108865163</td>
#       <td><a target=_blank href='https://www.wikidata.org/w/index.php?search=haswbstatement%3A%22P5587%3Dwt79ct3f3qbt3jd%22'>sök WD Librisid</a></td>
#       <td>BörkI</td>
#       <td>None</td>
#       <td>wt79ct3f3qbt3jd</td>
#       <td><a target=_blank href='https://libris.kb.se/wt79ct3f3qbt3jd'>link LIBRIS</a></td>
#     </tr>
#     <tr>
#       <th>360</th>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/CarlssonGottfrid'>link</a></td>
#       <td><a target=_blank href='https://litteraturbanken.se/f%C3%B6rfattare/CarlssonGottfrid'

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2023-03-02 19:34:45.249451
# Time elapsed (hh:mm:ss.ms) 0:00:05.063084
