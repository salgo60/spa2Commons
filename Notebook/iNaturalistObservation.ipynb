# %% [markdown]
# hämta observation [93568641](https://www.inaturalist.org/observations/93568641)
# * this [Notebook](https://github.com/salgo60/spa2Commons/blob/main/Notebook/iNaturalistObservation.ipynb)
#   * api [observations](https://www.inaturalist.org/observations.json)
#   * [projects user kueda.json](http://www.inaturalist.org/projects/user/kueda.json)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-09-06 11:18:04.669891

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 

obs = "93568641"
url = "http://www.inaturalist.org/observations/visbystar.json"
r = http.request('GET', url) 
data = json.loads(r.data.decode('utf-8'))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           id observed_on description       latitude      longitude map_scale  \
# 0   93703607  2021-09-05              57.6472236557  18.2964022665      None
# 1   93703567  2021-09-05              57.6474204424  18.2965675787      None
# 2   93703561  2021-09-05               57.647396521  18.2965240628      None
# 3   93703522  2021-09-05              57.6473967875  18.2965596824      None
# 4   93703515  2021-09-04              57.5973695738  18.3812708559      None
# 5   93570041  2021-09-04              57.5947066088   18.377578007      None
# 6   93570003  2021-09-04              57.5946708833  18.3778277204      None
# 7   93569913  2021-09-04              57.5944091173  18.3779062817      None
# 8   93568641  2021-09-04              57.5913717938  18.3741269856      None
# 9   93568612  2021-09-04              57.5913839973  18.3742810416      None
# 10  93568595  2021-09-04              57.5914667359  18.3743168644      None
# ...

# %%
dfNorm = pd.json_normalize(data)

# %%
dfNorm
# Out:
#           id observed_on description       latitude      longitude map_scale  \
# 0   93703607  2021-09-05              57.6472236557  18.2964022665      None
# 1   93703567  2021-09-05              57.6474204424  18.2965675787      None
# 2   93703561  2021-09-05               57.647396521  18.2965240628      None
# 3   93703522  2021-09-05              57.6473967875  18.2965596824      None
# 4   93703515  2021-09-04              57.5973695738  18.3812708559      None
# 5   93570041  2021-09-04              57.5947066088   18.377578007      None
# 6   93570003  2021-09-04              57.5946708833  18.3778277204      None
# 7   93569913  2021-09-04              57.5944091173  18.3779062817      None
# 8   93568641  2021-09-04              57.5913717938  18.3741269856      None
# 9   93568612  2021-09-04              57.5913839973  18.3742810416      None
# 10  93568595  2021-09-04              57.5914667359  18.3743168644      None
# ...
