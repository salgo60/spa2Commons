# %% [markdown]
# ## Picture depicts
# M185339187|P180|Q937

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2026-03-07 21:33:55.414611

# %%
import requests
import pandas as pd

SPARQL_COMMONS = "https://commons-query.wikimedia.org/sparql"

HEADERS = {
    "User-Agent": "SPA-sync-federated/1.0 (salgo60@msn.com)"
}

query = """
SELECT ?media ?spa ?person WHERE {

  # ?media wdt:P4819 ?spa .

  FILTER NOT EXISTS {
    # ?media wdt:P180 ?any
  }

  SERVICE <https://query.wikidata.org/sparql> {

    # ?person wdt:P2488 ?spa ;
            wdt:P31 wd:Q5 .

  }

}
"""

print("Running federated SPARQL...")

r = requests.get(
    SPARQL_COMMONS,
    params={"query": query, "format": "json"},
    headers=HEADERS,
    timeout=60
)

r.raise_for_status()

data = r.json()

rows = data["results"]["bindings"]

print("Rows:", len(rows))
# Out:
# Running federated SPARQL...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
import requests
import pandas as pd

SPARQL_COMMONS = "https://query.wikimedia.org/sparql"
SPARQL_WD = "https://query.wikidata.org/sparql"

HEADERS = {
    "User-Agent": "SPA-sync-sparql/1.0 (salgo60@msn.com)"
}

# ------------------------------------------------------------
# 1. Commons: MediaInfo with SPA ID but missing depicts
# ------------------------------------------------------------

query_commons = """
SELECT ?media ?spa WHERE {

  # ?media wdt:P4819 ?spa .

  FILTER NOT EXISTS {
    # ?media wdt:P180 ?any
  }

}
"""

r = requests.get(
    SPARQL_COMMONS,
    params={"query": query_commons, "format": "json"},
    headers=HEADERS,
)

r.raise_for_status()

commons_data = r.json()
commons_rows = commons_data["results"]["bindings"]

print("Commons rows:", len(commons_rows))


# ------------------------------------------------------------
# 2. Wikidata: SPA ID → person
# ------------------------------------------------------------

query_wd = """
SELECT ?person ?spa WHERE {
  # ?person wdt:P31 wd:Q5 ;
          wdt:P2488 ?spa .
}
"""

r = requests.get(
    SPARQL_WD,
    params={"query": query_wd, "format": "json"},
    headers=HEADERS,
)

r.raise_for_status()

wd_data = r.json()

spa_map = {}

for row in wd_data["results"]["bindings"]:
    spa = row["spa"]["value"]
    person = row["person"]["value"].split("/")[-1]
    spa_map[spa] = person

print("SPA persons loaded:", len(spa_map))


# ------------------------------------------------------------
# 3. Join Commons data with Wikidata mapping
# ------------------------------------------------------------

records = []

for row in commons_rows:

    media = row["media"]["value"].split("/")[-1]
    spa = row["spa"]["value"]

    person = spa_map.get(spa)

    if not person:
        continue

    records.append({
        "media": media,
        "spa": spa,
        "person": person
    })

df = pd.DataFrame(records)

print("Matches:", len(df))
display(df.head())


# ------------------------------------------------------------
# 4. Generate QuickStatements
# ------------------------------------------------------------

qs = []

for r in records:

    media = r["media"]
    spa = r["spa"]
    person = r["person"]

    qs.append(f'{media}|P4819|"{spa}"')
    qs.append(f"{media}|P180|{person}")


# ------------------------------------------------------------
# 5. Save file
# ------------------------------------------------------------

outfile = "quickstatements_spa_depicts_sparql.txt"

with open(outfile, "w") as f:
    f.write("\n".join(qs))

print("Statements written:", len(qs))
print("File:", outfile)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
qs[:10]

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
