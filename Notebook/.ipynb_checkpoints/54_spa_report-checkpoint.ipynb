# %% [markdown]
# ### Visualisera koppling SPA Wikicommons Wikidata Wikipedia
# * Notebook [54_spa_report](https://github.com/salgo60/spa2Commons/blob/main/Notebook/54_spa_report.ipynb)
# 1. Hämta alla bilder med koppling SPA
#    1. Wikicommons -> SPA
# 2. Hämta koppling Wikicommons bild Wikidata / Wikipedia
# 3. Skapa enkla csv filer för detta
